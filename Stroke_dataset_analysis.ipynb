# %%
#import pandas library
import pandas as pd
import matplotlib.pyplot as plt

# %%
#read the csv file containing data of stroke patients
df = pd.read_csv(r'C:\Users\Victor Keya\Documents\Flatiron\Stroke_data\stroke_data.csv')

# %%
#run the first 5 rows
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
#run the last 5 rows
df.tail()
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0

# %%
#understand the df types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
#understand the shape of the dateset
df.shape
# Out:
# (5110, 12)

# %%
#check for measures of central tendency
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %%
#check the columns of this data
df.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
#Change age from float to int
df['age'] = df['age'].astype(int)
df['age'].dtype
# Out:
# dtype('int32')

# %%
#check for duplicates
df.duplicated().value_counts()
# Out:
# False    5110
# dtype: int64

# %% [markdown]
# # We dont have duplicates

# %%
#check if we have any missing values
df.isna().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
#check propotion of missing values
df['bmi'].isna().mean()
# Out:
# 0.03933463796477495

# %%
#sample random data for missing values
bmi_missing = df[df['bmi'].isna()].sample(5, random_state=1)
bmi_missing
# Out:
#          id  gender  age  hypertension  heart_disease ever_married  \
# 1836   1818  Female   30             0              0           No
# 2477  24096  Female   34             1              0          Yes
# 1106  53817  Female   71             1              0          Yes
# 198   18937    Male   79             0              0          Yes
# 3705  11658    Male    1             0              0           No
#
#           work_type Residence_type  avg_glucose_level  bmi   smoking_status  \
# 1836       Govt_job          Urban              88.20  NaN           smokes
# 2477  Self-employed          Urban             100.61  NaN          Unknown
# 1106  Self-employed          Rural              66.12  NaN     never smoked
# 198         Private          Rural             114.77  NaN  formerly smoked
# 3705       children          Rural              74.50  NaN          Unknown
#
#       stroke
# 1836       0
# 2477       0
# 1106       0
# 198        1
# 3705       0

# %%
#sample random data for rows with bmi values
bmi_values = df[df['bmi'].notna()].sample(5, random_state=1)
bmi_values
# Out:
#          id  gender  age  hypertension  heart_disease ever_married  \
# 2648    641    Male   52             0              0          Yes
# 3441  57777  Female   59             0              0          Yes
# 4935  47691    Male   16             0              0           No
# 1316  45048  Female   21             0              0           No
# 3271  53271    Male   36             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 2648       Govt_job          Rural              87.26  40.1           smokes
# 3441  Self-employed          Urban              90.06  28.9           smokes
# 4935        Private          Rural              97.23  30.6     never smoked
# 1316        Private          Urban             134.45  29.1     never smoked
# 3271        Private          Rural              74.63  31.6  formerly smoked
#
#       stroke
# 2648       0
# 3441       0
# 4935       0
# 1316       0
# 3271       0

# %%
#before droping missing values lets work out mean, median and std dev for bmi column
df['bmi'].agg(['mean', 'median', 'std'])
# Out:
# mean      28.893237
# median    28.100000
# std        7.854067
# Name: bmi, dtype: float64

# %%
#drop rows with missing valuues and calculate measures of central tendency to compare before they were dropped
df =df.dropna()

# %%
#confirm missing values are not present int the dataset
df.isna().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
#Checking measures of central tendancy after values are dropped does not show any significant change in the calculation
df['bmi'].agg(['mean', 'median', 'std'])
# Out:
# mean      28.893237
# median    28.100000
# std        7.854067
# Name: bmi, dtype: float64

# %%
#Replacing the value 1 to yes in the hypertension column

df.loc[:, 'hypertension'] = df['hypertension'].replace({1: 'Yes'})
df
# Out:
#          id  gender  age hypertension  heart_disease ever_married  \
# 0      9046    Male   67            0              1          Yes
# 2     31112    Male   80            0              1          Yes
# 3     60182  Female   49            0              0          Yes
# 4      1665  Female   79          Yes              0          Yes
# 5     56669    Male   81            0              0          Yes
# ...     ...     ...  ...          ...            ...          ...
# 5104  14180  Female   13            0              0           No
# 5106  44873  Female   81            0              0          Yes
# 5107  19723  Female   35            0              0          Yes
# 5108  37544    Male   51            0              0          Yes
# 5109  44679  Female   44            0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# ...

# %%
#Replacing the value 0 to no in the hypertension column
df.loc[:, 'hypertension'] = df['hypertension'].replace({0: 'No'})

# %%
#doing the same for heart disease and stroke columns
df.loc[:, 'heart_disease'] = df['heart_disease'].replace({0: 'No'})
df.loc[:, 'heart_disease'] = df['heart_disease'].replace({1: 'Yes'})
df.loc[:, 'stroke'] = df['stroke'].replace({0: 'No'})
df.loc[:, 'stroke'] = df['stroke'].replace({1: 'Yes'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4909 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 4909 non-null   int64
#  1   gender             4909 non-null   object
#  2   age                4909 non-null   int32
#  3   hypertension       4909 non-null   object
#  4   heart_disease      4909 non-null   object
#  5   ever_married       4909 non-null   object
#  6   work_type          4909 non-null   object
#  7   Residence_type     4909 non-null   object
#  8   avg_glucose_level  4909 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     4909 non-null   object
#  11  stroke             4909 non-null   object
# dtypes: float64(2), int32(1), int64(1), object(8)
# memory usage: 479.4+ KB

# %%
#checking for uniques in columns
print(df['gender'].unique())
print(df['ever_married'].unique())
print(df['work_type'].unique())
print(df['Residence_type'].unique())
print(df['smoking_status'].unique())
print(df['stroke'].unique())
print(df['hypertension'].unique())
print(df['heart_disease'].unique())
# Out:
# ['Male' 'Female' 'Other']
# ['Yes' 'No']
# ['Private' 'Self-employed' 'Govt_job' 'children' 'Never_worked']
# ['Urban' 'Rural']
# ['formerly smoked' 'never smoked' 'smokes' 'Unknown']
# ['Yes' 'No']
# ['No' 'Yes']
# ['Yes' 'No']

# %%
#checking for outliers
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#check for outliers in the age column
sns.histplot(df['age'], bins=20, color='blue', edgecolor='black')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
#boxplot for age column to show any outliers
plt.boxplot(df['age'])
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('count')
plt.show()

# %%
#boxplot for bmi to show outliers

sns.boxplot(df['bmi'])
# Out:
# C:\Users\Victor Keya\Documents\Anaconda\envs\learn-env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bmi'>

# %%
#histogram for bmi showing outliers
sns.histplot(df['bmi'], bins=70, color='green', edgecolor='black')
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='Count'>

# %%
#checking average glucose level column for outliers
sns.histplot(df['avg_glucose_level'], bins=70, color='green', edgecolor='black')
# Out:
# <AxesSubplot:xlabel='avg_glucose_level', ylabel='Count'>

# %%
sns.boxplot(df['avg_glucose_level'])
# Out:
# C:\Users\Victor Keya\Documents\Anaconda\envs\learn-env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='avg_glucose_level'>

# %%
#Calculating quartile ranges to be able to hande outliers in the bmi column
Q1 = df['bmi'].quantile(0.25)
Q3 = df['bmi'].quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# 9.600000000000001

# %%
#removing outliers from bmi column
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df = df[(df['bmi'] >= lower_bound) & (df['bmi'] <= upper_bound)]

# %%
#boxplot showing outliers removed fro bmi column
sns.boxplot(df['bmi'])
# Out:
# C:\Users\Victor Keya\Documents\Anaconda\envs\learn-env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bmi'>

# %%
#Calculating quartile ranges to be able to hande outliers in the average glucose level column
Q1 = df['avg_glucose_level'].quantile(0.25)
Q3 = df['avg_glucose_level'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df = df[(df['avg_glucose_level'] >= lower_bound) & (df['avg_glucose_level'] <= upper_bound)]

# %%
#boxplot showing outliers removed fro avg_glucose_level column
sns.boxplot(df['avg_glucose_level'])
# Out:
# C:\Users\Victor Keya\Documents\Anaconda\envs\learn-env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='avg_glucose_level'>

# %%
# Out:
#          id  gender  age hypertension heart_disease ever_married  \
# 2     31112    Male   80           No           Yes          Yes
# 6     53882    Male   74          Yes           Yes          Yes
# 7     10434  Female   69           No            No           No
# 9     60491  Female   78           No            No          Yes
# 10    12109  Female   81          Yes            No          Yes
# ...     ...     ...  ...          ...           ...          ...
# 5104  14180  Female   13           No            No           No
# 5106  44873  Female   81           No            No          Yes
# 5107  19723  Female   35           No            No          Yes
# 5108  37544    Male   51           No            No          Yes
# 5109  44679  Female   44           No            No          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 2           Private          Rural             105.92  32.5     never smoked
# ...

# %%
#Explore the distribution of age, avg_glucose_level, and bmi

# Set up the figure with subplots
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(10, 12))

# Distribution plots for age, avg_glucose_level, and bmi
sns.histplot(df['age'], kde=True, ax=axes[0]).set_title('Distribution of Age')
sns.histplot(df['avg_glucose_level'], kde=True, ax=axes[1]).set_title('Distribution of Avg Glucose Level')
sns.histplot(df['bmi'], kde=True, ax=axes[2]).set_title('Distribution of BMI')

plt.tight_layout()
plt.show()

# %%
#Visualize the distribution of strokes in the dataset:

# Countplot for strokes
df['stroke'].value_counts().plot(kind='pie',autopct = '%1.1f%%')
plt.title('Strokes distribution ')
# Out:
# Text(0.5, 1.0, 'Strokes distribution ')

# %%
#Analyze the distribution of gender, work_type, and smoking_status with respect to strokes:

# Set up the figure with subplots
#fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(10, 12))
#
## Countplots for gender, work_type, and smoking_status with respect to strokes
#sns.countplot(x='gender', hue='stroke', data=df, ax=axes[0])
#axes[0].set_title('Distribution of Gender with respect to Strokes')
#
#sns.countplot(x='work_type', hue='stroke', data=df, ax=axes[1])
#axes[1].set_title('Distribution of Work Type with respect to Strokes')
#
#sns.countplot(x='smoking_status', hue='stroke', data=df, ax=axes[2])
#axes[2].set_title('Distribution of Smoking Status with respect to Strokes')
#
#sns.countplot(x='ever_married', hue='stroke', data=df, ax=axes[3])
#axes[2].set_title('Distribution of ever_married with respect to Strokes')
#
#plt.tight_layout()
#plt.show()

# %%
#Explore the correlation between hypertension, heart_disease, and strokes:

# Crosstab to analyze correlation
correlation_table = pd.crosstab(index=df['hypertension'], columns=[df['heart_disease'], df['stroke']], margins=True, margins_name="Total")
print(correlation_table)


# Plotting the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_table, annot=True, cmap='coolwarm', fmt='g', cbar=True)
plt.title('Correlation Heatmap: Hypertension, Heart Disease, and Strokes')
plt.show()
#This heatmap will visually represent the correlations between hypertension, heart disease, and strokes. 
#Positive correlations will be represented by warmer colors, while negative correlations will be represented 
#by cooler colors. The annotations will display the actual count values.
# Out:
# heart_disease    No       Yes     Total
# stroke           No  Yes   No Yes
# hypertension
# No             3752   90  109  14  3965
# Yes             231   28   28   4   291
# Total          3983  118  137  18  4256

# %%
#correlation between numeric columns
df.corr()
# Out:
#                          id       age  avg_glucose_level       bmi
# id                 1.000000  0.018739           0.021095  0.022499
# age                0.018739  1.000000          -0.025502  0.379036
# avg_glucose_level  0.021095 -0.025502           1.000000  0.003728
# bmi                0.022499  0.379036           0.003728  1.000000

# %%
#Correlate Age and Stroke
# Line plot
plt.figure(figsize=(10, 6))
sns.lineplot(x='age', y='stroke', data=df, alpha=0.5)
plt.title('Line Plot: Age vs. Stroke')
plt.xlabel('Age')
plt.ylabel('Stroke')
plt.show()

# %%
#Correlate bmi and Stroke
# Line plot
plt.figure(figsize=(10, 6))
sns.lineplot(x='bmi', y='stroke', data=df, alpha=0.5)
plt.title('Line Plot: bmi vs. Stroke')
plt.xlabel('bmi')
plt.ylabel('Stroke')
plt.show()

# %%
#Correlate smoking status and Stroke
# Line plot
plt.figure(figsize=(10, 6))
sns.lineplot(x='smoking_status', y='stroke', data=df, alpha=0.5)
plt.title('Line Plot: smoking_status vs. Stroke')
plt.xlabel('smoking_status')
plt.ylabel('Stroke')
plt.show()

# %%
#Correlate gender and Stroke
# Line plot
plt.figure(figsize=(10, 6))
sns.lineplot(x='gender', y='stroke', data=df, alpha=0.5)
plt.title('Line Plot: gender vs. Stroke')
plt.xlabel('gender')
plt.ylabel('Stroke')
plt.show()

# %%
#Correlate work_type and Stroke
# Line plot
plt.figure(figsize=(10, 6))
sns.lineplot(x='work_type', y='stroke', data=df, alpha=0.5)
plt.title('Line Plot: work_type vs. Stroke')
plt.xlabel('work_type')
plt.ylabel('Stroke')
plt.show()

# %%
#Correlate hypertension and Stroke
# Line plot
plt.figure(figsize=(10, 6))
sns.lineplot(x='hypertension', y='stroke', data=df, alpha=0.5)
plt.title('Line Plot: hypertension vs. Stroke')
plt.xlabel('hypertension')
plt.ylabel('Stroke')
plt.show()

# %%
#Correlate heart_disease and Stroke
# Line plot
plt.figure(figsize=(10, 6))
sns.lineplot(x='heart_disease', y='stroke', data=df, alpha=0.5)
plt.title('Line Plot: heart_disease vs. Stroke')
plt.xlabel('heart_disease')
plt.ylabel('Stroke')
plt.show()

# %%
#Use any tool i.e. groupby, pivot tables and crosstab to perform any additional analyses that you find relevant:

grouped_gender_stroke = df.groupby(['gender', 'stroke']).size().unstack()
print(grouped_gender_stroke)

# Example of using pivot_table
pivot_age_stroke = df.pivot_table(index='age', columns='stroke', aggfunc='size', fill_value=0)
print(pivot_age_stroke)
pivot_age_stroke
# Out:
# stroke      No   Yes
# gender
# Female  2447.0  82.0
# Male    1672.0  54.0
# Other      1.0   NaN
# stroke  No  Yes
# age
# 0       42    0
# 1       69    0
# 2       55    0
# 3       44    0
# 4       33    0
# ..      ..  ...
# 78      60   13
# 79      54    8
# 80      38   12
# 81      36   10
# 82      34    5
#
# [83 rows x 2 columns]
# stroke  No  Yes
# age
# 0       42    0
# 1       69    0
# 2       55    0
# 3       44    0
# 4       33    0
# ..      ..  ...
# 78      60   13
# 79      54    8
# 80      38   12
# 81      36   10
# 82      34    5
#
# [83 rows x 2 columns]

# %%
grouped_gender_stroke
# Out:
# stroke      No   Yes
# gender
# Female  2447.0  82.0
# Male    1672.0  54.0
# Other      1.0   NaN

# %%
pivot_age_stroke
# Out:
# stroke  No  Yes
# age
# 0       42    0
# 1       69    0
# 2       55    0
# 3       44    0
# 4       33    0
# ..      ..  ...
# 78      60   13
# 79      54    8
# 80      38   12
# 81      36   10
# 82      34    5
#
# [83 rows x 2 columns]

# %%
# Visualization for gender and stroke
plt.figure(figsize=(12, 6))
grouped_gender_stroke.plot(kind='bar', stacked=True, color=['#63ace5', '#ff7c7c'])
plt.title('Gender Distribution by Stroke')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Stroke', labels=['No Stroke', 'Stroke'])
plt.show()

# %%
# Visualization for age and stroke using Matplotlib
plt.figure(figsize=(12, 6))
plt.plot(pivot_age_stroke.index, pivot_age_stroke['No'], label='No Stroke')
plt.plot(pivot_age_stroke.index, pivot_age_stroke['Yes'], label='Stroke')
plt.title('Age Distribution by Stroke')
plt.xlabel('Age')
plt.ylabel('Count')
plt.legend(title='Stroke')
plt.show()

# %%
#using pivot table to find relationships between gender and marriage status with stroke
pivot_gender_stroke = df.pivot_table(index=['gender', 'ever_married'], columns='stroke', aggfunc='size', fill_value=0)
print(pivot_gender_stroke)
pivot_gender_stroke
# Out:
# stroke                 No  Yes
# gender ever_married
# Female No             892   14
#        Yes           1555   68
# Male   No             701    5
#        Yes            971   49
# Other  No               1    0
# stroke                 No  Yes
# gender ever_married
# Female No             892   14
#        Yes           1555   68
# Male   No             701    5
#        Yes            971   49
# Other  No               1    0

# %%
# Visualization for gender, ever_married and stroke using Matplotlib
plt.figure(figsize=(12, 6))
sns.heatmap(pivot_gender_stroke, annot=True, cmap='coolwarm', fmt='g', cbar=True)
plt.title('Pivot Table: Gender, Ever Married, and Stroke')
plt.show()

# %%
# Calculate mean BMI for different stroke groups
mean_bmi_by_stroke = df.groupby('stroke')['bmi'].mean()

# Print the mean BMI values
print(mean_bmi_by_stroke)
mean_bmi_by_stroke
# Out:
# stroke
# No     27.778155
# Yes    28.956618
# Name: bmi, dtype: float64
# stroke
# No     27.778155
# Yes    28.956618
# Name: bmi, dtype: float64

# %%
#using pivot table to find relationships between hyprtension and heart_disease with stroke
pivot_hypertension_stroke = df.pivot_table(index=['hypertension', 'heart_disease'], columns='stroke', aggfunc='size', fill_value=0)
print(pivot_hypertension_stroke)
pivot_hypertension_stroke
# Out:
# stroke                        No  Yes
# hypertension heart_disease
# No           No             3752   90
#              Yes             109   14
# Yes          No              231   28
#              Yes              28    4
# stroke                        No  Yes
# hypertension heart_disease
# No           No             3752   90
#              Yes             109   14
# Yes          No              231   28
#              Yes              28    4

# %%
# Visualization for hyprtension and heart_disease and stroke using Matplotlib
plt.figure(figsize=(12, 6))
sns.heatmap(pivot_hypertension_stroke, annot=True, cmap='coolwarm', fmt='g', cbar=True)
plt.title('Pivot Table: hypertension, heart_disease, and Stroke')
plt.show()

# %%
# Set the style for the plots
sns.set(style="whitegrid")

# Visualization for BMI distribution by stroke
plt.figure(figsize=(12, 6))
sns.histplot(data=df, x='bmi', hue='stroke', multiple='stack', kde=True)
plt.title('BMI Distribution by Stroke')
plt.xlabel('BMI')
plt.ylabel('Count')
plt.show()

# Visualization for Age distribution by stroke
plt.figure(figsize=(12, 6))
sns.histplot(data=df, x='age', hue='stroke', multiple='stack', kde=True)
plt.title('Age Distribution by Stroke')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# Visualization for Gender distribution by stroke
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='gender', hue='stroke')
plt.title('Gender Distribution by Stroke')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
#plotting avg glucose level with stroke

# Set style
sns.set(style="whitegrid")

# Visualization for avg_glucose_level distribution by stroke
plt.figure(figsize=(12, 6))
sns.histplot(data=df, x='avg_glucose_level', hue='stroke', multiple='stack', kde=True)
plt.title('avg_glucose_level Distribution by Stroke')
plt.xlabel('avg_glucose_level')
plt.ylabel('Count')
plt.show()

# %%
#Summary and Findings
"""

Stroke Distribution
For the dataset provided a smaller subset of the population about 3% have stroke, the rest 97% do not have stroke.

People who  formerly smoked are at a higher risk of getting stroke, smokers and people who have never smoked have
an equal chance.

People with higher bmi are at risk of getting stroke.

For Age people above 40 years all the way to 80 years are susceptible to stroke with 40 years being slightly affected with 80 years
being severly affected..

The likelihood of a female who is married to have stroke is higher compared to a male who is also married.

Hypertension and stroke have a positive correlation, as hypertension goes up, likelihood of stroke increases.

Heart_disease and stroke have a positive correlation, as heart_disease goes up, likelihood of stroke increases.


"""
# Out:
# '\n\nStroke Distribution\nFor the dataset provided a smaller subset of the population about 3% have stroke, the rest 97% do not have stroke.\n\nPeople who  formerly smoked are at a higher risk of getting stroke, smokers and people who have never smoked have\nan equal chance.\n\nPeople with higher bmi are at risk of getting stroke.\n\nFor Age people above 40 years all the way to 80 years are susceptible to stroke with 40 years being slightly affected with 80 years\nbeing severly affected..\n\nThe likelihood of a female who is married to have stroke is higher compared to a male who is also married.\n\nHypertension and stroke have a positive correlation, as hypertension goes up, likelihood of stroke increases.\n\nHeart_disease and stroke have a positive correlation, as heart_disease goes up, likelihood of stroke increases.\n\n\n'

# %%
#recommendations.

"""
This dataset has a very low prevalence of people with stroke, i would recommend to expand the dataset to accomodate a 
significant number of people for this population.

Also i would want to understand how genetics(if any family member has had a stroke), also how ethnicity(race) influences stroke.

And also if the person has ever had ulcers or been under depression or stress.
"""
# Out:
# '\nThis dataset has a very low prevalence of people with stroke, i would recommend to expand the dataset to accomodate a \nsignificant number of people for this population.\n\nAlso i would want to understand how genetics(if any family member has had a stroke), also how ethnicity(race) influences stroke.\n\nAnd also if the person has ever had ulcers or been under depression or stress.\n'
